# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
data = pd.read_csv("data_before_vi.csv")
data1 = pd.read_csv("data_before_vi.csv")
data2 = pd.read_csv("data_before_vi.csv")

# %%
data.shape
# Out:
# (1239, 27)

# %%
data.head()
# Out:
#    Unnamed: 0  UNITID  TYPE  FORPROFIT  BOARD  TUITION1_INDISTRICT_UG  \
# 0           0  100654     1          0      1                    8610
# 1           1  100706     1          0      1                    9730
# 2           2  100724     1          0      1                    8328
# 3           3  100751     1          0      0                   10780
# 4           4  100830     1          0      0                    7992
#
#    FEE1_INDISTRICT_UG  OFFCAMPUS_SELF_EXP  OFFCAMPUS_FAMILY_EXP  \
# 0                1414                3090                  3440
# 1                1608                4076                  4076
# 2                2740                4228                  4228
# 3                 840                4620                  5692
# 4                 868                3830                  3830
#
#    ADMS_REQUIRED_COLLEGEPREP  ...  PRCENT_FLOANS_TOUG  STATE      HLOFFER  \
# 0                          0  ...                  75  SOUTH  Highest_Doc
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'UNITID', 'TYPE', 'FORPROFIT', 'BOARD',
#        'TUITION1_INDISTRICT_UG', 'FEE1_INDISTRICT_UG', 'OFFCAMPUS_SELF_EXP',
#        'OFFCAMPUS_FAMILY_EXP', 'ADMS_REQUIRED_COLLEGEPREP', 'NUM_APPS_ADMIT',
#        'FULLTIME_RETENTIONRATE_SPRING', 'STUD_TO_FAL_RATIO',
#        'PRCNT_FIRSTYR_UG', 'PRCNT_UG_AWARDEDAID', 'PRCNT_UG_AWARDED_PELL',
#        'TOTAL_AMOUNT_PELL_TOUG', 'PRCENT_FLOANS_TOUG', 'STATE', 'HLOFFER',
#        'TEACHER_CERT', 'TUITION_GURANTEE', 'TOTAL_ASSETS',
#        'TOTAL_SPENT_ACADEMICSUPP', 'TOTAL_SPENT_STUDENTSS', 'STATEGRANT',
#        'LOCAL_GRANT'],
#       dtype='object')

# %%
data.drop("Unnamed: 0",axis=1,inplace=True)

# %%
data.head()
# Out:
#    UNITID  TYPE  FORPROFIT  BOARD  TUITION1_INDISTRICT_UG  FEE1_INDISTRICT_UG  \
# 0  100654     1          0      1                    8610                1414
# 1  100706     1          0      1                    9730                1608
# 2  100724     1          0      1                    8328                2740
# 3  100751     1          0      0                   10780                 840
# 4  100830     1          0      0                    7992                 868
#
#    OFFCAMPUS_SELF_EXP  OFFCAMPUS_FAMILY_EXP  ADMS_REQUIRED_COLLEGEPREP  \
# 0                3090                  3440                          0
# 1                4076                  4076                          0
# 2                4228                  4228                          0
# 3                4620                  5692                          1
# 4                3830                  3830                          0
#
# ...

# %% [markdown]
# # Seperating data types

# %%
def seperate_colnames(dataframe):
    global catcols,numcols
    catcols = []
    numcols= []
    for item in dataframe:
        if item == "UNITID":
            continue
            #dummy variables and string values for levels 
        if dataframe[item].max() ==1 or dataframe[item].dtype ==object:
            catcols.append(item)
        else:
            numcols.append(item)
    print(numcols)
    print()
    print(catcols)

# %%
seperate_colnames(data)
# Out:
# ['TUITION1_INDISTRICT_UG', 'FEE1_INDISTRICT_UG', 'OFFCAMPUS_SELF_EXP', 'OFFCAMPUS_FAMILY_EXP', 'NUM_APPS_ADMIT', 'FULLTIME_RETENTIONRATE_SPRING', 'STUD_TO_FAL_RATIO', 'PRCNT_FIRSTYR_UG', 'PRCNT_UG_AWARDEDAID', 'PRCNT_UG_AWARDED_PELL', 'TOTAL_AMOUNT_PELL_TOUG', 'PRCENT_FLOANS_TOUG', 'TOTAL_ASSETS', 'TOTAL_SPENT_ACADEMICSUPP', 'TOTAL_SPENT_STUDENTSS', 'STATEGRANT', 'LOCAL_GRANT']
#
# ['TYPE', 'FORPROFIT', 'BOARD', 'ADMS_REQUIRED_COLLEGEPREP', 'STATE', 'HLOFFER', 'TEACHER_CERT', 'TUITION_GURANTEE']

# %%
def numdf(dataframe):
    global numdata
    for col in dataframe.columns:
        if col not in numcols:
            col = col
            del dataframe[col]
    numdata = dataframe
    return dataframe.head()


def catdf(dataframe):
    global catdata
    for col in dataframe.columns:
        if col not in catcols:
            col = col
            del dataframe[col]
    catdata = dataframe
    return dataframe.head()

# %%
numdf(data1)
# Out:
#    TUITION1_INDISTRICT_UG  FEE1_INDISTRICT_UG  OFFCAMPUS_SELF_EXP  \
# 0                    8610                1414                3090
# 1                    9730                1608                4076
# 2                    8328                2740                4228
# 3                   10780                 840                4620
# 4                    7992                 868                3830
#
#    OFFCAMPUS_FAMILY_EXP  NUM_APPS_ADMIT  FULLTIME_RETENTIONRATE_SPRING  \
# 0                  3440            9855                             54
# 1                  4076            5793                             82
# 2                  4228            7027                             62
# 3                  5692           39560                             87
# 4                  3830            4606                             70
#
#    STUD_TO_FAL_RATIO  PRCNT_FIRSTYR_UG  PRCNT_UG_AWARDEDAID  \
# 0                 18                32                   87
# ...

# %%
numdata.shape
# Out:
# (1239, 17)

# %%
catdf(data2)
# Out:
#    TYPE  FORPROFIT  BOARD  ADMS_REQUIRED_COLLEGEPREP  STATE      HLOFFER  \
# 0     1          0      1                          0  SOUTH  Highest_Doc
# 1     1          0      1                          0  SOUTH  Highest_Doc
# 2     1          0      1                          0  SOUTH  Highest_Doc
# 3     1          0      0                          1  SOUTH  Highest_Doc
# 4     1          0      0                          0  SOUTH  Highest_Doc
#
#    TEACHER_CERT  TUITION_GURANTEE
# 0             1                 0
# 1             1                 0
# 2             1                 0
# 3             1                 0
# 4             1                 0

# %%
catdata.shape
# Out:
# (1239, 8)

# %% [markdown]
# # Data frames
# catdata = categorical features
# numdata = numerical features
# data = full data frame

# %% [markdown]
# # Descriptive Stats

# %%
stat1=round(numdata.describe(),3)
stat1 = stat1.T
stat1['coefvar'] =stat1['std'] / stat1['mean']
stat1.rename(columns = {'50%': 'median'}, inplace= True)
stat1 = stat1.loc[:, ['count', 'mean', 'median', 'std', 'coefvar', 'min', 'max']]

# %% [markdown]
# # Not worried features

# %%
stat1.iloc[0:12,:]
# Out:
#                                  count         mean       median  \
# TUITION1_INDISTRICT_UG        1,239.00    24,383.56    24,700.00
# FEE1_INDISTRICT_UG            1,239.00     1,470.85     1,150.00
# OFFCAMPUS_SELF_EXP            1,239.00     3,659.20     3,380.00
# OFFCAMPUS_FAMILY_EXP          1,239.00     3,885.93     3,572.00
# NUM_APPS_ADMIT                1,239.00     7,359.40     3,629.00
# FULLTIME_RETENTIONRATE_SPRING 1,239.00        75.83        77.00
# STUD_TO_FAL_RATIO             1,239.00        13.79        13.00
# PRCNT_FIRSTYR_UG              1,239.00        20.55        21.00
# PRCNT_UG_AWARDEDAID           1,239.00        80.47        84.00
# PRCNT_UG_AWARDED_PELL         1,239.00        34.85        34.00
# TOTAL_AMOUNT_PELL_TOUG        1,239.00 8,636,779.55 3,348,648.00
# PRCENT_FLOANS_TOUG            1,239.00        53.07        54.00
#
#                                         std  coefvar    min            max
# ...

# %% [markdown]
# # Features worried

# %%
stat1.iloc[12:,:]
# Out:
#                             count           mean         median  \
# TOTAL_ASSETS             1,239.00 781,641,575.20 232,223,214.00
# TOTAL_SPENT_ACADEMICSUPP 1,239.00  25,698,185.32   6,710,398.00
# TOTAL_SPENT_STUDENTSS    1,239.00  19,937,941.75  11,508,007.00
# STATEGRANT               1,239.00  31,935,348.46  14,850,000.00
# LOCAL_GRANT              1,239.00 123,554,158.13  25,625,786.00
#
#                                       std  coefvar        min  \
# TOTAL_ASSETS             2,153,757,016.15     2.76 934,251.00
# TOTAL_SPENT_ACADEMICSUPP    64,783,275.42     2.52       0.00
# TOTAL_SPENT_STUDENTSS       29,371,563.89     1.47       0.00
# STATEGRANT                  58,740,256.84     1.84       0.00
# LOCAL_GRANT                603,987,522.45     4.89       0.00
#
#                                        max
# TOTAL_ASSETS             30,413,231,000.00
# TOTAL_SPENT_ACADEMICSUPP  1,012,266,000.00
# TOTAL_SPENT_STUDENTSS       439,695,909.00
# ...

# %%
private = data[data['TYPE']==0]
public = data[data['TYPE']==1]

# %%
stat2=round(private.describe(),3)
stat2 = stat2.T
stat2['coefvar'] =stat2['std'] / stat2['mean']
stat2.rename(columns = {'50%': 'median'}, inplace= True)
stat2 = stat2.loc[:, ['count', 'mean', 'median', 'std', 'coefvar', 'min', 'max']]

# %%
stat2.iloc[22:]
# Out:
#              count           mean        median            std  coefvar  \
# STATEGRANT  803.00  41,909,964.15 22,768,560.00  68,244,404.57     1.63
# LOCAL_GRANT 803.00 172,343,795.92 51,192,900.00 678,610,220.48     3.94
#
#                    min               max
# STATEGRANT        0.00    711,990,000.00
# LOCAL_GRANT 668,084.00 10,944,686,000.00

# %%
stat3=round(public.describe(),3)
stat3 = stat3.T
stat3['coefvar'] =stat3['std'] / stat3['mean']
stat3.rename(columns = {'50%': 'median'}, inplace= True)
stat3 = stat3.loc[:, ['count', 'mean', 'median', 'std', 'coefvar', 'min', 'max']]
stat3[22:]
# Out:
#              count          mean       median            std  coefvar  min  \
# STATEGRANT  436.00 13,564,668.66 4,985,420.00  26,670,775.19     1.97 0.00
# LOCAL_GRANT 436.00 33,696,178.42         0.00 420,347,726.62    12.47 0.00
#
#                          max
# STATEGRANT    234,169,000.00
# LOCAL_GRANT 7,653,947,000.00

# %%
tuit1_small = data[data['TYPE']==1]
tuit1_small[["UNITID","TUITION1_INDISTRICT_UG","BOARD","TYPE","FEE1_INDISTRICT_UG"]]
# Out:
#       UNITID  TUITION1_INDISTRICT_UG  BOARD  TYPE  FEE1_INDISTRICT_UG
# 0     100654                    8610      1     1                1414
# 1     100706                    9730      1     1                1608
# 2     100724                    8328      1     1                2740
# 3     100751                   10780      0     1                 840
# 4     100830                    7992      0     1                 868
# ...      ...                     ...    ...   ...                 ...
# 1217  482680                    3969      0     1                1365
# 1218  482936                    3152      1     1                1788
# 1220  484905                    6678      1     1                1466
# 1225  486840                    4450      1     1                1986
# 1238  495767                   15025      0     1                 488
#
# [436 rows x 5 columns]

# %% [markdown]
# Drop this instance

# %%
data.drop(963,axis=0,inplace=True)

# %%
tuit1_small[["UNITID","TUITION1_INDISTRICT_UG","BOARD","TYPE","FEE1_INDISTRICT_UG"]]
# Out:
#       UNITID  TUITION1_INDISTRICT_UG  BOARD  TYPE  FEE1_INDISTRICT_UG
# 0     100654                    8610      1     1                1414
# 1     100706                    9730      1     1                1608
# 2     100724                    8328      1     1                2740
# 3     100751                   10780      0     1                 840
# 4     100830                    7992      0     1                 868
# ...      ...                     ...    ...   ...                 ...
# 1217  482680                    3969      0     1                1365
# 1218  482936                    3152      1     1                1788
# 1220  484905                    6678      1     1                1466
# 1225  486840                    4450      1     1                1986
# 1238  495767                   15025      0     1                 488
#
# [436 rows x 5 columns]

# %%
numapps_small = data[data['NUM_APPS_ADMIT']<30]
numapps_small[["NUM_APPS_ADMIT","TYPE"]]
# Out:
#       NUM_APPS_ADMIT  TYPE
# 124               24     0
# 421               18     0
# 494                2     0
# 625                9     0
# 649               17     0
# 685               18     0
# 695                1     0
# 732               12     0
# 819               22     0
# 935                5     0
# 1195              14     0
# 1199              26     0
# 1203               0     0
# 1209               8     0
# 1213               4     0
# 1228               1     0
# 1231              16     0
# 1233              23     0

# %%
stat1.iloc[12:,:]
# Out:
#                             count           mean         median  \
# TOTAL_ASSETS             1,239.00 781,641,575.20 232,223,214.00
# TOTAL_SPENT_ACADEMICSUPP 1,239.00  25,698,185.32   6,710,398.00
# TOTAL_SPENT_STUDENTSS    1,239.00  19,937,941.75  11,508,007.00
# STATEGRANT               1,239.00  31,935,348.46  14,850,000.00
# LOCAL_GRANT              1,239.00 123,554,158.13  25,625,786.00
#
#                                       std  coefvar        min  \
# TOTAL_ASSETS             2,153,757,016.15     2.76 934,251.00
# TOTAL_SPENT_ACADEMICSUPP    64,783,275.42     2.52       0.00
# TOTAL_SPENT_STUDENTSS       29,371,563.89     1.47       0.00
# STATEGRANT                  58,740,256.84     1.84       0.00
# LOCAL_GRANT                603,987,522.45     4.89       0.00
#
#                                        max
# TOTAL_ASSETS             30,413,231,000.00
# TOTAL_SPENT_ACADEMICSUPP  1,012,266,000.00
# TOTAL_SPENT_STUDENTSS       439,695,909.00
# ...

# %%
fee1_small = data[data['FEE1_INDISTRICT_UG']<200]
fee1_small[["UNITID","TUITION1_INDISTRICT_UG","BOARD","TYPE","FEE1_INDISTRICT_UG"]].head()
# Out:
#      UNITID  TUITION1_INDISTRICT_UG  BOARD  TYPE  FEE1_INDISTRICT_UG
# 89   121257                   55734      1     0                 144
# 146  131469                   55961      0     0                  88
# 159  133711                   19940      1     0                 100
# 223  141486                   26800      1     0                 114
# 258  147660                   41000      0     0                 180

# %% [markdown]
# # Graphing Numerical

# %%
sns.histplot(data = data, x="TUITION1_INDISTRICT_UG", hue="TYPE")
plt.title(' In-district average tuition for undergraduates', fontsize=16)
plt.xlabel('', fontsize=16)
plt.ylabel('Frequency', fontsize=16)
plt.show()

# %%
sns.histplot(data = data, x="FEE1_INDISTRICT_UG", hue="TYPE")
plt.title(' In-district required fees for undergraduates', fontsize=18)
plt.xlabel('', fontsize=16)
plt.ylabel('Frequency', fontsize=16)
plt.plot()
# Out:
# []

# %%
sns.histplot(data = data, x="OFFCAMPUS_SELF_EXP", hue="TYPE")
plt.title(' Students Off campus (self) Expenses', fontsize=18)
plt.xlabel('', fontsize=16)
plt.ylabel('Frequency', fontsize=16)
plt.plot()
# Out:
# []

# %%
sns.histplot(data = data, x="OFFCAMPUS_FAMILY_EXP", hue="TYPE")
plt.title(' Students Off campus (family) Expenses', fontsize=18)
plt.xlabel('', fontsize=16)
plt.ylabel('Frequency', fontsize=16)
plt.plot()
# Out:
# []

# %%
sns.histplot(data = data, x="NUM_APPS_ADMIT", hue="TYPE")
plt.title('Number of Applicants Admitted', fontsize=18)
plt.xlabel('', fontsize=16)
plt.ylabel('Frequency', fontsize=16)
plt.plot()
# Out:
# []

# %%
catdata.columns
# Out:
# Index(['TYPE', 'FORPROFIT', 'BOARD', 'ADMS_REQUIRED_COLLEGEPREP', 'STATE',
#        'HLOFFER', 'TEACHER_CERT', 'TUITION_GURANTEE'],
#       dtype='object')

# %%
sns.histplot(data = data, x="FULLTIME_RETENTIONRATE_SPRING", hue="TYPE")
plt.title('SPRING Full time Retention Rate', fontsize=18)
plt.xlabel('', fontsize=16)
plt.ylabel('Frequency', fontsize=16)
plt.plot()
# Out:
# []

# %%
sns.histplot(data = data, x="STUD_TO_FAL_RATIO", hue="TYPE")
plt.title('Student to faculty ratio', fontsize=18)
plt.xlabel('', fontsize=16)
plt.ylabel('Frequency', fontsize=16)
plt.plot()
# Out:
# []

# %%
sns.histplot(data = data, x="PRCNT_FIRSTYR_UG", hue="TYPE")
plt.title('Percent of first year undergraduates', fontsize=18)
plt.xlabel('', fontsize=16)
plt.plot()
# Out:
# []

# %%
sns.histplot(data = data, x="PRCNT_UG_AWARDEDAID", hue="TYPE")
plt.title('Percent of undergraduates awarded AID', fontsize=18)
plt.xlabel('', fontsize=16)
plt.ylabel('Frequency', fontsize=16)
plt.plot()
# Out:
# []

# %%
sns.histplot(data = data, x="PRCNT_UG_AWARDED_PELL", hue="TYPE")
plt.title('Percent of undergraduates awarded PELL', fontsize=18)
plt.xlabel('', fontsize=16)
plt.ylabel('Frequency', fontsize=16)
plt.plot()
# Out:
# []

# %%
sns.histplot(data = data, x="TOTAL_AMOUNT_PELL_TOUG", hue="TYPE")
plt.title('Total amount of PELL to undergraduates ', fontsize=18)
plt.xlabel('', fontsize=16)
plt.plot()
# Out:
# []

# %%
sns.histplot(data = data, x="PRCENT_FLOANS_TOUG", hue="TYPE")
plt.title('Percent of Loans given to undergraduates', fontsize=18)
plt.xlabel('', fontsize=16)
plt.plot()
# Out:
# []

# %% [markdown]
# # Weird Distributions

# %%
sns.histplot(data = data, x="TOTAL_SPENT_STUDENTSS", hue="TYPE")
plt.title('Total spent on students services', fontsize=18)
plt.xlabel('', fontsize=16)
plt.ylabel('Frequency', fontsize=16)
plt.plot()
# Out:
# []

# %%
sns.histplot(data = data, x="TOTAL_SPENT_ACADEMICSUPP", hue="TYPE")
plt.title('Total spent on Academic Support', fontsize=18)
plt.xlabel('', fontsize=16)
plt.ylabel('Frequency', fontsize=16)
plt.plot()
# Out:
# []

# %%
0.2E9
# Out:
# 200000000.0

# %%
sns.histplot(data = data, x="TOTAL_ASSETS", hue="TYPE")
plt.title('Total Assets ', fontsize=18)
plt.xlabel('', fontsize=16)
plt.ylabel('Frequency', fontsize=16)
plt.plot()
# Out:
# []

# %%
sns.histplot(data = data, x="STATEGRANT", hue="TYPE")
plt.title('Total State Awarded Grants ', fontsize=18)
plt.xlabel('', fontsize=16)
plt.ylabel('Frequency', fontsize=16)
plt.plot()
# Out:
# []

# %%
sns.histplot(data = data, x="LOCAL_GRANT", hue="TYPE")
plt.title('Total Local Awarded Grants', fontsize=18)
plt.xlabel('', fontsize=16)
plt.ylabel('Frequency', fontsize=16)
plt.plot()
# Out:
# []

# %% [markdown]
# # Categorical

# %%
catdata
# Out:
#       TYPE  FORPROFIT  BOARD  ADMS_REQUIRED_COLLEGEPREP    STATE  \
# 0        1          0      1                          0    SOUTH
# 1        1          0      1                          0    SOUTH
# 2        1          0      1                          0    SOUTH
# 3        1          0      0                          1    SOUTH
# 4        1          0      0                          0    SOUTH
# ...    ...        ...    ...                        ...      ...
# 1234     0          0      1                          1    NORTH
# 1235     0          0      1                          1    NORTH
# 1236     0          0      1                          1    NORTH
# 1237     0          1      1                          0  MidWest
# 1238     1          0      0                          0    NORTH
#
#                HLOFFER  TEACHER_CERT  TUITION_GURANTEE
# 0          Highest_Doc             1                 0
# 1          Highest_Doc             1                 0
# ...

# %%
catdata[["TYPE","FORPROFIT","BOARD","ADMS_REQUIRED_COLLEGEPREP","TEACHER_CERT","TUITION_GURANTEE"]].sum(axis=0)
# Out:
# TYPE                          436
# FORPROFIT                     496
# BOARD                         645
# ADMS_REQUIRED_COLLEGEPREP     464
# TEACHER_CERT                 1056
# TUITION_GURANTEE               98
# dtype: int64

# %%
catdata["HLOFFER"].value_counts()
# Out:
# Highest_Doc            673
# Highest_Masters        308
# Highest_Bachelor       161
# Highest_PostMasters     97
# Name: HLOFFER, dtype: int64

# %%
state = ["DOCTORATE","POST MASTERS","MASTERS","BACHELOR"]
statecount= [673,308,161,97]
fig, ax = plt.subplots(figsize=(10,8))
sns.barplot(x=state, y=statecount, palette="rocket")
plt.title("Highest Level of Education Offered")

plt.plot()
# Out:
# []

# %%
catdata["STATE"].value_counts()
# Out:
# SOUTH          463
# NORTH          334
# MidWest        285
# WEST           154
# OtherRegion      3
# Name: STATE, dtype: int64

# %%
state = ["SOUTH","NORTH","MIDWEST","WEST","OTHER"]
statecount= [463,334,285,154,3]
fig, ax = plt.subplots(figsize=(10,8))
sns.barplot(x=state, y=statecount, palette="husl")
plt.title("Region of the University ")

plt.plot()
# Out:
# []

# %% [markdown]
# # TYPE

# %%
x = ['Public',"Private"]
y = [436,803]
plt.title("Type of University")
colors = ["#6FA5A8","#F6E1D3"]
sns.set(font_scale = 1.30)
#create pie chart
plt.pie(y, labels = x, colors = colors, autopct='%.0f%%')
plt.show()

# %%
1239-464
# Out:
# 775

# %%
x = ['Yes',"No"]
y = [464,775]
plt.title("Admissions requires compeltion of College Prep")
colors = ["#6FA5A8","#F6E1D3"]
sns.set(font_scale = 1.30)
#create pie chart
plt.pie(y, labels = x, colors = colors, autopct='%.0f%%')
plt.show()

# %% [markdown]
# # For Profit

# %%
x = ['For Profit',"Not for Profit"]
y = [496,743]
plt.title("Type of University")
colors = ["#6FA5A8","#F6E1D3"]
sns.set(font_scale = 1.30)
#create pie chart
plt.pie(y, labels = x, colors = colors, autopct='%.0f%%')
plt.show()

# %% [markdown]
# # Room and Board

# %%
x = ['Yes',"No"]
y = [645,594]
plt.title("Offers Board")
colors = ["#6FA5A8","#F6E1D3"]
sns.set(font_scale = 1.30)
#create pie chart
plt.pie(y, labels = x, colors = colors, autopct='%.0f%%')
plt.show()

# %%
1239-1056
# Out:
# 183

# %% [markdown]
# # Teacher Certification

# %%
x = ['Yes',"No"]
y = [1056,83]
plt.title("Offers a Teaching Certification")
colors = ["#6FA5A8","#F6E1D3"]
sns.set(font_scale = 1.30)
#create pie chart
plt.pie(y, labels = x, colors = colors, autopct='%.0f%%')
plt.show()

# %% [markdown]
# # TUITION_GURANTEE

# %%
1239-  98
# Out:
# 1141

# %%
x = ['No change',"Can Change"]
y = [ 98,1141]
plt.title("University guarantees Tution will not increase over time")
colors = ["#6FA5A8","#F6E1D3"]
sns.set(font_scale = 1.30)
#create pie chart
plt.pie(y, labels = x, colors = colors, autopct='%.0f%%')
plt.show()

# %% [markdown]
# # Categorical and Numeric

# %%
catdf = pd.DataFrame([])
for col in catcols:
    for num in numcols:
        category = data.groupby(col)[num].describe()
        category['NumericalCategory'] = num
        category['category'] = col
        catdf = catdf.append(category)

# %% [markdown]
# # Categories with the biggest difference

# %%
forprofit1=catdf.iloc[34:36,:]
forprofit2 = catdf.iloc[42:44,:]
forprofit3 =catdf.iloc[54:56,:]
forprofit4=catdf.iloc[58:60,:]
forprofit5 = catdf.iloc[60:62,:]
forprofit6=catdf.iloc[66:68,:]
board1=catdf.iloc[92:94,:]
board2=catdf.iloc[94:96,:]
board3= catdf.iloc[96:98,:]
board4 = catdf.iloc[100:102,:]
prep1 = catdf.iloc[126:128,:]
prep2 = catdf.iloc[128:130,:]
state1 = catdf.iloc[186:191,:]
state2 = catdf.iloc[211:216,:]
state3 =catdf.iloc[216:221,:]
highest1 = catdf.iloc[237:241,:]
highest2 = catdf.iloc[261:265,:]
highest3 = catdf.iloc[269:273,:]
highest4 = catdf.iloc[273:281,:]
highest5 = catdf.iloc[281:289,:]
tuit1 = catdf.iloc[323:325,:]
tuit2 = catdf.iloc[343:345,:]
tuit3 = catdf.iloc[347:360,:]

# %%
forprofit = forprofit1.append(forprofit2)
forprofit = forprofit.append(forprofit3)
forprofit = forprofit.append(forprofit4)
forprofit = forprofit.append(forprofit5)
forprofit = forprofit.append(forprofit6)
forprofit
# Out:
#    count             mean              std          min            25%  \
# 0 742.00        19,893.66        17,386.52       910.00       7,029.50
# 1 496.00        31,149.32        10,615.88     4,776.00      24,675.00
# 0 742.00         9,805.70        12,306.72         0.00       2,410.00
# 1 496.00         3,709.58         5,556.89         1.00       1,172.75
# 0 742.00    12,411,955.23    16,388,059.73         0.00   2,330,268.50
# 1 496.00     3,000,603.54     4,482,347.01         0.00   1,532,909.00
# 0 742.00 1,075,823,654.93 2,558,067,968.53 1,690,872.00 153,700,370.75
# 1 496.00   342,702,777.49 1,217,448,860.12   934,251.00  66,873,044.00
# 0 742.00    37,634,987.10    80,238,874.32         0.00   4,670,443.50
# 1 496.00     7,872,727.80    18,056,667.27    12,720.00   1,484,565.00
# 0 742.00   146,214,022.67   735,545,802.27         0.00           0.00
# 1 496.00    89,904,832.86   317,070,577.43   794,338.00  25,087,049.50
#
# ...

# %%
sns.set_style(style='white')
ax = sns.violinplot(x="FORPROFIT", y="TUITION1_INDISTRICT_UG", data=data,palette="Set3",inner="box",linewidth =1.75)
fig.set_size_inches(20, 15)
plt.xlabel('For Profit', fontsize=16)
plt.ylabel('Dollars', fontsize=16)
plt.title('Average Tuition Amount', fontsize=16)
plt.plot()
# Out:
# []

# %%
sns.set_style(style='white')
ax = sns.violinplot(x="FORPROFIT", y="TOTAL_AMOUNT_PELL_TOUG", data=data,palette="Set3",inner="box",linewidth =1.75)
fig.set_size_inches(20, 15)
plt.xlabel('For Profit', fontsize=16)
plt.ylabel('In Billions', fontsize=16)
plt.title('Total Pell', fontsize=16)
plt.plot()
# Out:
# []

# %%
ax = sns.violinplot(x="FORPROFIT", y="NUM_APPS_ADMIT", data=data,palette="Set3",inner="box",linewidth =1.75)
fig.set_size_inches(20, 15)
plt.xlabel('For Profit', fontsize=16)
plt.ylabel('Number', fontsize=16)
plt.title('Total Applicants Admitted', fontsize=16)
plt.plot()
# Out:
# []

# %%
ax = sns.violinplot(x="FORPROFIT", y="TOTAL_ASSETS", data=data,palette="Set3",inner="box",linewidth =1.75)
fig.set_size_inches(20, 15)
plt.xlabel('For Profit', fontsize=16)
plt.ylabel('In Billions', fontsize=16)
plt.title('Total Assets', fontsize=16)
plt.plot()
# Out:
# []

# %%
ax = sns.violinplot(x="FORPROFIT", y="TOTAL_SPENT_ACADEMICSUPP", data=data,palette="Set3",inner="box",linewidth =1.75)
fig.set_size_inches(20, 15)
plt.xlabel('For Profit', fontsize=16)
plt.ylabel('In Billions', fontsize=16)
plt.title('Total Spent Academic Support', fontsize=16)
plt.plot()
# Out:
# []

# %%
ax = sns.violinplot(x="FORPROFIT", y="LOCAL_GRANT", data=data,palette="Set3",inner="box",linewidth =1.75)
fig.set_size_inches(20, 15)
plt.xlabel('For Profit', fontsize=16)
plt.ylabel('In Billions', fontsize=16)
plt.title('Total Amount of Local Grants', fontsize=16)
plt.plot()
# Out:
# []

# %%
boardf= board1.append(board2)
boardf= boardf.append(board3)
boardf= boardf.append(board4)
boardf
# Out:
#    count             mean              std          min            25%  \
# 0 594.00 1,038,181,381.30 2,584,049,268.50 5,726,996.00 157,893,026.75
# 1 644.00   545,903,709.78 1,629,730,476.26   934,251.00  69,027,247.50
# 0 594.00    35,756,630.77    76,507,895.75   266,572.00   4,732,530.75
# 1 644.00    16,445,022.89    50,025,587.18         0.00   1,717,432.75
# 0 594.00    25,726,526.24    35,249,506.70         0.00   8,449,975.75
# 1 644.00    14,613,613.99    21,344,341.11     2,304.00   4,725,572.00
# 0 594.00   159,399,408.71   744,185,896.20         0.00           0.00
# 1 644.00    90,683,778.18   435,119,162.21         0.00     769,680.00
#
#              50%            75%               max         NumericalCategory  \
# 0 313,946,493.00 806,537,984.00 30,413,231,000.00              TOTAL_ASSETS
# 1 158,023,171.50 374,467,605.25 18,413,619,000.00              TOTAL_ASSETS
# 0  11,286,116.50  30,275,926.50  1,012,266,000.00  TOTAL_SPENT_ACADEMICSUPP
# ...

# %%
ax = sns.violinplot(x="BOARD", y="TOTAL_ASSETS", data=data,palette="Set3",inner="box",linewidth =1.75)
fig.set_size_inches(20, 15)
plt.xlabel('Board', fontsize=14)
plt.ylabel('In Billions', fontsize=16)
plt.title('Total Assets', fontsize=16)
plt.plot()
# Out:
# []

# %%
ax = sns.violinplot(x="BOARD", y="TOTAL_SPENT_ACADEMICSUPP", data=data,palette="Set3",inner="box",linewidth =1.75)
fig.set_size_inches(20, 15)
plt.xlabel('Board', fontsize=16)
plt.ylabel('In Billions', fontsize=16)
plt.title('Total Spent on Academic Support', fontsize=16)
plt.plot()
# Out:
# []

# %%
ax = sns.violinplot(x="BOARD", y="TOTAL_SPENT_STUDENTSS", data=data,palette="Set3",inner="box",linewidth =1.75)
fig.set_size_inches(20, 15)
plt.xlabel('Board', fontsize=16)
plt.ylabel('In Billions', fontsize=16)
plt.title('Total Spent on Student Services', fontsize=16)
plt.plot()
# Out:
# []

# %%
ax = sns.violinplot(x="BOARD", y="LOCAL_GRANT", data=data,palette="Set3",inner="box",linewidth =1.75)
fig.set_size_inches(20, 15)
plt.xlabel('Board', fontsize=16)
plt.ylabel('In Billions', fontsize=16)
plt.title('Total Local Grants', fontsize=16)
plt.plot()
# Out:
# []

# %%
prepdf= prep1.append(prep2)
prepdf
# Out:
#    count             mean              std          min            25%  \
# 0 775.00   560,245,713.59 1,917,592,567.23   934,251.00  77,085,254.50
# 1 463.00 1,153,458,534.68 2,459,291,606.78 1,690,872.00 172,673,000.00
# 0 775.00    18,878,251.91    63,216,144.62         0.00   1,907,105.00
# 1 463.00    37,147,706.67    65,887,536.93         0.00   5,022,732.50
#
#              50%              75%               max         NumericalCategory  \
# 0 173,713,560.00   366,519,026.50 30,413,231,000.00              TOTAL_ASSETS
# 1 367,323,248.00 1,004,424,132.50 23,155,618,000.00              TOTAL_ASSETS
# 0   4,509,691.00    13,093,962.00  1,012,266,000.00  TOTAL_SPENT_ACADEMICSUPP
# 1  13,640,213.00    39,086,623.00    525,499,169.00  TOTAL_SPENT_ACADEMICSUPP
#
#                     category
# 0  ADMS_REQUIRED_COLLEGEPREP
# 1  ADMS_REQUIRED_COLLEGEPREP
# 0  ADMS_REQUIRED_COLLEGEPREP
# 1  ADMS_REQUIRED_COLLEGEPREP

# %%
ax = sns.violinplot(x="ADMS_REQUIRED_COLLEGEPREP", y="TOTAL_ASSETS", data=data,palette="Set3",inner="box",linewidth =1.75)
fig.set_size_inches(20, 15)
plt.xlabel('Required Colleg Prep', fontsize=16)
plt.ylabel('In Billions', fontsize=16)
plt.title('Total Assets', fontsize=16)
plt.plot()
# Out:
# []

# %%
ax = sns.violinplot(x="ADMS_REQUIRED_COLLEGEPREP", y="TOTAL_SPENT_ACADEMICSUPP", data=data,palette="Set3",inner="box",linewidth =1.75)
fig.set_size_inches(20, 15)
plt.xlabel('Required Colleg Prep', fontsize=16)
plt.ylabel('In Billions', fontsize=16)
plt.title('Total Spent on Academic Support', fontsize=16)
plt.plot()
# Out:
# []

# %%
statedf= state1.append(state2)
statedf = statedf.append(state3)
statedf
# Out:
#              count           mean            std          min          25%  \
# MidWest     285.00   5,577,018.21   7,442,549.22         0.00 1,538,166.00
# NORTH       334.00   6,279,801.81  10,436,076.59     9,640.00 1,800,360.75
# OtherRegion   3.00   3,786,791.00   1,200,815.82 2,400,407.00 3,430,031.50
# SOUTH       462.00  10,384,236.48  14,582,107.79         0.00 2,162,106.75
# WEST        154.00  14,299,925.47  22,038,871.47   195,011.00 1,651,250.75
# MidWest     285.00  27,836,244.29  50,848,481.68         0.00 4,438,229.00
# NORTH       334.00  44,981,583.97  77,457,166.29         0.00 7,136,172.75
# OtherRegion   3.00           0.00           0.00         0.00         0.00
# SOUTH       462.00  24,127,478.86  42,676,230.64         0.00 2,850,955.25
# WEST        154.00  35,447,066.21  62,849,351.16         0.00 4,919,794.75
# MidWest     285.00  75,523,812.72 280,786,405.88         0.00         0.00
# ...

# %%
highestdf = highest1.append(highest2)
highestdf = highestdf.append(highest3)
highestdf = highestdf.append(highest4)
highestdf = highestdf.append(highest5)
highestdf[0:12]
# Out:
#                      count             mean              std           min  \
# Highest_Bachelor    161.00         2,432.80         2,642.06          0.00
# Highest_Doc         673.00        10,894.65        12,920.21         14.00
# Highest_Masters     308.00         3,042.91         3,968.22          1.00
# Highest_PostMasters  96.00         4,737.32         4,247.94          2.00
# Highest_Bachelor    161.00     2,014,340.91     2,935,922.58          0.00
# Highest_Doc         673.00    13,050,747.59    17,105,150.13          0.00
# Highest_Masters     308.00     3,394,711.99     3,930,585.51     38,460.00
# Highest_PostMasters  96.00     5,676,425.32     5,682,482.50     44,265.00
# Highest_Bachelor    161.00   261,951,496.84   522,941,986.86    934,251.00
# Highest_Doc         673.00 1,246,619,890.55 2,821,851,320.41  2,634,460.00
# Highest_Masters     308.00   210,440,425.56   290,411,205.77  2,117,740.00
# ...

# %%
ax = sns.violinplot(x="NUM_APPS_ADMIT", y="HLOFFER", data=data,palette="Set3",inner="box",linewidth =1.75,orient="h")
fig.set_size_inches(20, 15)
plt.xlabel('Number', fontsize=16)
plt.ylabel('Highest Level Offered', fontsize=16)
plt.title('Total Applicants Admitted', fontsize=16)
plt.plot()
# Out:
# []

# %%
ax = sns.violinplot(x="TOTAL_AMOUNT_PELL_TOUG", y="HLOFFER", data=data,palette="Set3",inner="box",linewidth =1.75,orient="h")
fig.set_size_inches(20, 15)
plt.xlabel('In Billions', fontsize=16)
plt.ylabel('Highest Level Offered', fontsize=16)
plt.title('Total Amount Pell', fontsize=16)
plt.plot()
# Out:
# []

# %%
ax = sns.violinplot(x="TOTAL_ASSETS", y="HLOFFER", data=data,palette="Set3",inner="box",linewidth =1.75,orient="h")
fig.set_size_inches(20, 15)
plt.xlabel('In Billions', fontsize=16)
plt.ylabel('Highest Level Offered', fontsize=16)
plt.title('Total Assets', fontsize=16)
plt.plot()
# Out:
# []

# %%
highestdf[12:]
# Out:
#                      count           mean            std        min  \
# Highest_Bachelor    161.00   3,959,561.61   5,371,171.01       0.00
# Highest_Doc         673.00  42,637,301.16  84,037,059.68 388,773.00
# Highest_Masters     308.00   5,494,748.98   7,300,399.11  12,720.00
# Highest_PostMasters  96.00   8,388,100.30   7,264,839.87 283,658.00
# Highest_Bachelor    161.00   7,492,208.32   8,538,916.54   2,304.00
# Highest_Doc         673.00  28,976,810.89  36,800,209.71       0.00
# Highest_Masters     308.00   9,297,043.25   8,088,382.57  15,258.00
# Highest_PostMasters  96.00  11,683,285.48   7,084,576.08 203,397.00
# Highest_Bachelor    161.00  16,755,482.61  19,639,648.21       0.00
# Highest_Doc         673.00  44,086,674.24  75,744,583.94       0.00
# Highest_Masters     308.00  17,484,192.94  18,170,899.41       0.00
# Highest_PostMasters  96.00  18,852,356.32  19,238,005.01       0.00
# Highest_Bachelor    161.00  36,909,548.49  47,213,050.15       0.00
# ...

# %%
ax = sns.violinplot(x="TOTAL_SPENT_ACADEMICSUPP", y="HLOFFER", data=data,palette="Set3",inner="box",linewidth =1.75,orient="h")
fig.set_size_inches(20, 15)
plt.xlabel('In Billions', fontsize=16)
plt.ylabel('Highest Level Offered', fontsize=16)
plt.title('Total Spent Academic Support', fontsize=16)
plt.plot()
# Out:
# []

# %%
ax = sns.violinplot(x="STATEGRANT", y="HLOFFER", data=data,palette="Set3",inner="box",linewidth =1.75,orient="h")
fig.set_size_inches(20, 15)
plt.xlabel('In Billions', fontsize=16)
plt.ylabel('Highest Level Offered', fontsize=16)
plt.title('Total State Grants', fontsize=16)
plt.plot()
# Out:
# []

# %%
ax = sns.violinplot(x="LOCAL_GRANT", y="HLOFFER", data=data,palette="Set3",inner="box",linewidth =1.75,orient="h")
fig.set_size_inches(20, 15)
plt.xlabel('In Billions', fontsize=16)
plt.ylabel('Highest Level Offered', fontsize=16)
plt.title('Total Local Grants', fontsize=16)
plt.plot()
# Out:
# []

# %%
tuitdf = tuit1.append(tuit2)
tuitdf = tuitdf.append(tuit3)
tuitdf
# Out:
#      count             mean              std          min            25%  \
# 0 1,140.00        25,417.92        15,939.34       910.00       9,259.50
# 1    98.00        12,599.30        11,682.79     2,530.00       5,796.75
# 0 1,140.00     7,727,030.11    12,959,162.01         0.00   1,752,660.50
# 1    98.00    19,277,100.18    18,152,672.95    27,753.00   5,187,452.00
# 0 1,140.00   735,728,008.45 2,110,030,177.04   934,251.00  97,877,220.25
# 1    98.00 1,321,548,979.18 2,569,229,410.28 2,668,985.00 227,022,286.00
# 0 1,140.00    23,783,687.64    63,894,010.03         0.00   2,397,068.50
# 1    98.00    48,128,872.45    71,225,833.74    71,949.00   7,097,085.25
# 0 1,140.00    19,262,936.12    29,244,036.80         0.00   6,051,042.75
# 1    98.00    27,887,518.53    29,968,445.78    44,262.00   8,888,745.25
# 0 1,140.00    32,943,029.00    59,974,562.69         0.00   4,037,172.50
# 1    98.00    20,488,459.55    40,609,748.98         0.00   4,873,911.00
# ...

# %%
ax = sns.violinplot(x="TUITION_GURANTEE", y="TUITION1_INDISTRICT_UG", data=data,palette="Set3",inner="box",linewidth =1.75)
fig.set_size_inches(20, 15)
plt.xlabel('Required Colleg Prep', fontsize=16)
plt.ylabel('In One hundred Million', fontsize=16)
plt.title('Total Assets', fontsize=16)
plt.plot()
# Out:
# []

# %%
ax = sns.violinplot(x="TUITION_GURANTEE", y="TOTAL_AMOUNT_PELL_TOUG", data=data,palette="Set3",inner="box",linewidth =1.75)
fig.set_size_inches(20, 15)
plt.xlabel('Required Colleg Prep', fontsize=16)
plt.ylabel('Total Assets', fontsize=16)
plt.plot()
# Out:
# []

# %%
ax = sns.violinplot(x="TUITION_GURANTEE", y="TOTAL_ASSETS", data=data,palette="Set3",inner="box",linewidth =1.75)
fig.set_size_inches(20, 15)
plt.xlabel('Required Colleg Prep', fontsize=16)
plt.ylabel('Total Assets', fontsize=16)
plt.plot()
# Out:
# []

# %%
ax = sns.violinplot(x="TUITION_GURANTEE", y="TOTAL_SPENT_ACADEMICSUPP", data=data,palette="Set3",inner="box",linewidth =1.75)
fig.set_size_inches(20, 15)
plt.xlabel('Required Colleg Prep', fontsize=16)
plt.ylabel('Total Assets', fontsize=16)
plt.plot()
# Out:
# []

# %%
ax = sns.violinplot(x="TUITION_GURANTEE", y="TOTAL_SPENT_ACADEMICSUPP", data=data,palette="Set3",inner="box",linewidth =1.75)
fig.set_size_inches(20, 15)
plt.xlabel('Required Colleg Prep', fontsize=16)
plt.ylabel('Total Assets', fontsize=16)
plt.plot()
# Out:
# []

# %%
ax = sns.violinplot(x="TUITION_GURANTEE", y="STATEGRANT", data=data,palette="Set3",inner="box",linewidth =1.75)
fig.set_size_inches(20, 15)
plt.xlabel('Required Colleg Prep', fontsize=16)
plt.ylabel('In Billions', fontsize=16)
plt.title('State Grant', fontsize=16)
plt.plot()
# Out:
# []

# %%
ax = sns.violinplot(x="TUITION_GURANTEE", y="LOCAL_GRANT", data=data,palette="Set3",inner="box",linewidth =1.75)
fig.set_size_inches(20, 15)
plt.xlabel('Required Colleg Prep', fontsize=16)
plt.ylabel('In 100 million dollars ', fontsize=16)
plt.title('Local Grant', fontsize=16)
plt.plot()
# Out:
# []
